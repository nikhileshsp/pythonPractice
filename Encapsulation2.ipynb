# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.__age=age
    def get_age(self):
        return self.__age

    def set_age(self,age):
        self.__age=age

stud= Student("Adarsh",24)

# retriving age using getter
print("name:",stud.name,stud.get_age())
# hanging age using setter
stud.set_age(21)
# retriving age using getter
print("Name:",stud.name,stud.get_age())
# Out:
# name: Adarsh 24
# Name: Adarsh 21

# %%
class Student:
    def __init__(self,name,roll_no,age):
        self.name= name
        self.__roll_no= roll_no
        self.__age= age

    def show(self):
        print("Student Details: ",self.name,self.__roll_no)

    def get_roll_no(self):
        return self.__roll_no

    def set_roll_no(self,number):
        if number>50:
            print('Invalid roll number. Please set correct roll number')
        else:
            self.__roll_no= number

s1= Student('Sonali',10,25)
s1.show()

# changing roll no using setter

s1.set_roll_no(120)
s1.set_roll_no(25)
s1.show()
# Out:
# Student Details:  Sonali 10
# Invalid roll number. Please set correct roll number
# Student Details:  Sonali 25
