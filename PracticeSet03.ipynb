# %%
#  String & String Formatting String Questions:

#  01

user_input = input("Enter a string: ")

reversed_string = user_input[::-1]

print(f"The reversed string is: {reversed_string}")
# Out:
# Enter a string:  dgdgd
# The reversed string is: dgdgd

# %%
#  02

user_input = input("Enter a string: ")
length = len(user_input.replace(" ", ""))
print(f"The length of the string (excluding spaces) is: {length}")
# Out:
# Enter a string:  nikhil Patil
# The length of the string (excluding spaces) is: 11

# %%
#  03

user_string = input("Enter a string: ")
character = input("Enter the character to count: ")
count = user_string.count(character)
print(count)
# Out:
# Enter a string:  nikhil
# Enter the character to count:  i
# 2

# %%
#  04

first = str(input(" enter first name"))
mid = str(input(" enter mid name"))
last = str(input(" enter last name"))
First= first.upper()
Mid= mid.upper()
Last= last.upper()

print("Full upper name is : ", First," ",Mid," ",Last)
# Out:
#  enter first name nikhilesh
#  enter mid name subhash
#  enter last name patil
# Full upper name is :  NIKHILESH    SUBHASH    PATIL

# %%
#  05

first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Enter your first name:  nikhilesh
# Enter your last name:  patil
# nikhilesh patil

# %%
#  06

user_input = input("Enter a string: ")

if len(user_input) >= 3:
    first_three = user_input[:3]  
    last_three = user_input[-3:]
    print(first_three)
    print(last_three)
else:
    print("The string is too short to slice!")
# Out:
# Enter a string:  nikhilesh
# nik
# esh

# %%
#  07

user_input = input("Enter a string: ")

reversed_string = user_input[::-1]

print(reversed_string)
# Out:
# Enter a string:  nikhilesh
# hselihkin

# %%
#  08

email = input("Enter an email address: ")
if "@" in email:
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Enter an email address:  nikhileshspatil@gmail.com
# Valid email

# %%
#  Combining Strings and Numbers Questions:

#  01

weight = float(input("Enter your weight in kilograms: "))
height = float(input("Enter your height in meters: "))
bmi = weight / (height ** 2)
print(f"Your BMI is: {bmi:.2f}")
if bmi < 18.5:
    print("You are underweight.")
elif 18.5 <= bmi < 24.9:
    print("You have a normal weight.")
elif 25 <= bmi < 29.9:
    print("You are overweight.")
else:
    print("You are obese.")
# Out:
# Enter your weight in kilograms:  48
# Enter your height in meters:  5.8
# Your BMI is: 1.43
# You are underweight.

# %%
#  02

birth_year = int(input("Enter your birth year: "))

current_year = 2025
age = current_year - birth_year
print(age)
# Out:
# Enter your birth year:  2000
# 25

# %%
#  03


name = input("Enter your name: ")
age = input("Enter your age: ")
print("your name is ",name,"and ","age is",age)
# Out:
# Enter your name:  nikhilesh
# Enter your age:  28
# your name is  nikhilesh and  age is 28

# %%
#  04


principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the interest rate (in %): "))
time = float(input("Enter the time period (in years): "))

simple_interest = (principal * rate * time) / 100

print("The simple interest is: ",simple_interest)
# Out:
# Enter the principal amount:  4855
# Enter the interest rate (in %):  4
# Enter the time period (in years):  2
# The simple interest is:  388.4

# %%
#  05


number = int(input("Enter an integer (up to 999): "))
ones = ["", "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine"]
teens = ["Ten", "Eleven", "Twelve", "Thirteen", "Fourteen", "Fifteen", "Sixteen", "Seventeen", "Eighteen", "Nineteen"]
tens = ["", "", "Twenty", "Thirty", "Forty", "Fifty", "Sixty", "Seventy", "Eighty", "Ninety"]

if number == 0:
    print("Zero")
elif number < 10:
    print(ones[number])
elif number < 20:
    print(teens[number - 10])
elif number < 100:
    print(tens[number // 10] + " " + ones[number % 10])
else:  
    hundreds = ones[number // 100] + " Hundred"
    remainder = number % 100
    if remainder < 10:
        words = hundreds + " " + ones[remainder]
    elif remainder < 20:
        words = hundreds + " " + teens[remainder - 10]
    else:
        words = hundreds + " " + tens[remainder // 10] + " " + ones[remainder % 10]
    print(words.strip())
# Out:
# Enter an integer (up to 999):  254
# Two Hundred Fifty Four
