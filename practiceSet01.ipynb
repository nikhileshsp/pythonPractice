# %%
# 01 

age =10
print(age)
# Out:
# 10

# %%
# 02  
name= "nikhilesh"
firstname= name
print(firstname)
# Out:
# nikhilesh

# %%
# 03

x=10
y=20
temp =x
x= y
y= temp

print(x)
print(y)
# Out:
# 20
# 10

# %%
# 04 

x=10
y= str(x)
print(type(y))
# Out:
# <class 'str'>

# %%
# 05

num1 = input(str("Enter a number: "))
print(type(num1))

number = int(num1)

result = number * 2

print("mult:", result)

print(type(result))
# Out:
# Enter a number:  45
# <class 'str'>
# mult: 90
# <class 'int'>

# %%
# 06
9num= "10"
print(9num)
print(type(9num))
# Out:
#   Cell In[1], line 2
#     9num= "10"
#     ^
# SyntaxError: invalid decimal literal

# %%
# 07

Student_Name_Is= "Nikhilesh"
studentNameIs= "Nikhilesh p"

print(Student_Name_Is)
print(studentNameIs)
# Out:
# Nikhilesh
# Nikhilesh p
