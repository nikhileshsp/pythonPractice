# %%
# while lpoop

i= 0
while i<5:
    print(i)
    i +=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i= 0
while i<5:
    print(i,end=" ")
    i +=1
# Out:
# 0 1 2 3 4

# %%
languages= ['Swift','Python','Go','JavaScript']

i=0

while i< len(languages):
    print(languages[i])
    i +=1

# %%
digit=[0,1,5]

i=0
while i<len(digit):
    print(digit[i])
    i +=1
else:
    print("no item left")
# Out:
# 0
# 1
# 5
# no item left

# %%
words= ["Apple","Banana","Car","Dolphin"]
a=0
while a<len(words):
    current_word = words[a]
    print("The following lines will print each letter of "+ current_word)
    b=0
    while b<len(current_word):
        current_letter= current_word[b]
        print(current_letter)
        b+=1
    print("")
    a+=1

# %%
total = 0
i=1
while i<=100:
    total+=i
    i +=1
print("The sum is: ",total)
# Out:
# The sum is:  5050

# %%
sum_even= 0
sum_odd= 0

i=1
while i<=100:
    if i%2==0:
        sum_even+=i
    else:
        sum_odd+=i
    i+=1
print("Sum of even no is :",sum_even)
print("Sum of Odd is: ",sum_odd)
# Out:
# Sum of even no is : 2550
# Sum of Odd is:  2500

# %%
mydata= [1,2,3,4,5,6,7,8]
i=0
while i<len(mydata):
    if mydata[i]==3:
        break
    print(mydata[i])
    i+=1

# %%
mydata= [1,2,3,4,5,6,7,8]
i=0
while i<len(mydata):
    if mydata[i]==3:
        i+=1
    print(mydata[i])
    i+=1

# %%
mydata= [1,2,3,4,5,6,7,8]
i=0
while i<len(mydata):
    print(mydata[i])
    if mydata[i]==3:
       # i+=1
        continue
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
a= ['nikhil','nikhilesh','jatin','purab']
b= ['mansi','chankshi','preeti','neha']

for i in a:
    if i=='nikhil':
        continue
    if i=='jatin':
        break
    print(i)
for i in b:
    if i=='mansi':
        continue
    if i=='preeti':
        break
    print(i)
for i in b:
    if i=='neha':
        print(i)
for i in a:
    if i=='purab':
        print(i)
for i in b:
    if i=='mansi':
        continue
    if i=='preeti':
        break
    print(i)
for i in b:
    if i=='neha':
        print(i)
# Out:
# nikhilesh
# chankshi
# neha
# purab
# chankshi
# neha

# %%
#  17-03-2025

a= int(input("Enter number of rows"))

b=0
while b<a:
    c=0
    while c<b+1:
        print("* ",end="")
        c+=1
    print("\n")
    b+=1
# Out:
# Enter number of rows 6
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * * * *

# %%
a= 2
i=1
while i<=1:
    b=1
    while b<=10:
        print(a,"*","=",a*b)
        b+=1
    i+=1
# Out:
# 2 * = 2
# 2 * = 4
# 2 * = 6
# 2 * = 8
# 2 * = 10
# 2 * = 12
# 2 * = 14
# 2 * = 16
# 2 * = 18
# 2 * = 20

# %%
a="user123"
b="password123"
attempts=3
while attempts>0:
    username=input("Enter the username")
    if username==a:
        password=input("Enter the password")
        if password==b:
            print("Login successfull! welcome,"+username)
            break
        else:
            attempts-=1
            print("password is incorrect. You have",attempts,"attempts left.")
    else:
       if attempts==0:
        print("You have run out of attempts. program ending")
# Out:
# Enter the username user748
# Enter the username usee456
# Enter the username user520
# Enter the username user555
# Enter the username user123
# Enter the password user452
# password is incorrect. You have 2 attempts left.
# Enter the username user4522
# Enter the username pass441
# Enter the username user123
# Enter the password SAS
# password is incorrect. You have 1 attempts left.
# Enter the username user123
# Enter the password dfdg
# password is incorrect. You have 0 attempts left.

# %%
for i in range(3):
    age = int(input(f"Enter the age of user {i+1}:"))
    if age >=18:
        print(f"user {i+1} is eligible for voting")
    else:
        print(f"user {1+1} is not eligible for voting")
# Out:
# Enter the age of user 1: 24
# user 1 is eligible for voting
# Enter the age of user 2: 63
# user 2 is eligible for voting
# Enter the age of user 3: 14
# user 2 is not eligible for voting

# %%
a = 2
b = 3
c = 4
for i in range(1, 11):
    print(f"{a} * {i} = {a*i}\t {b*i}\t {c*i}")
# Out:
# 2 * 1 = 2	 3	 4
# 2 * 2 = 4	 6	 8
# 2 * 3 = 6	 9	 12
# 2 * 4 = 8	 12	 16
# 2 * 5 = 10	 15	 20
# 2 * 6 = 12	 18	 24
# 2 * 7 = 14	 21	 28
# 2 * 8 = 16	 24	 32
# 2 * 9 = 18	 27	 36
# 2 * 10 = 20	 30	 40
