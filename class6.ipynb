# %%
# contitional statement using if statement

a= 33
b= 100
if a>b:
    print("yes")
if b>a:
    print("may be")
# Out:
# may be

# %%
a= ["yellow","pink","green","gray"]
if "red" in a :
    print('it is true')
    print('we found pink in a')
    print('thatshow its true')
    print('done')
print('There was a some error in the if Condition')
# Out:
# There was a some error in the if Condition

# %%
a= ["yellow","pink","green","gray"]
if "pink" in a :
    print('it is true')
    print('we found pink in a')
    print('thatshow its true')
    print('done')
print('There was a some error in the if Condition')
# Out:
# it is true
# we found pink in a
# thatshow its true
# done
# There was a some error in the if Condition

# %%
# 

a= 33
b= 100
if b<a:
    print("b is lesser then a")
elif a==b:
    print("a is not equal to b")
elif a<b:
    print("a is lesser then b")
elif a!=b:
    print("a is not equal to b")
# Out:
# a is lesser then b

# %%
a= 33
b= 100
if b<a:
    print("b is lesser then a")
if a==b:
    print("a is not equal to b")
if a<b:
    print("a is lesser then b")
if a!=b:
    print("a is not equal to b")
# Out:
# a is lesser then b
# a is not equal to b

# %%
a= 200
b= 33
if b>a:
    print("b is greater then a")
elif a!=b:
    print("a and b are not equal")
else:
    print("a is greater then b")
# Out:
# a and b are not equal
