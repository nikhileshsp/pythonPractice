# %%
#  26-03-25
# create and print dictionary


a= {
    "name":"Rashmi",
    "DOB":"05th jul",
    "PLace":"Nanital",
    "Age":34
}

print(a)
# Out:
# {'name': 'Rashmi', 'DOB': '05th jul', 'PLace': 'Nanital', 'Age': 34}

# %%
b= {"name":"Rashmi","DOB":"05th jul","PLace":"Nanital", "Age":34}

print(b)
# Out:
# {'name': 'Rashmi', 'DOB': '05th jul', 'PLace': 'Nanital', 'Age': 34}

# %%
e= {
    "name":"Rashmi",
    "PLace":"Nanital",
    "Food":"Momo",
    "Color":"Pink",
    "name":"Riya",
}
print(len(e))
print(e)
# Out:
# 4
# {'name': 'Riya', 'PLace': 'Nanital', 'Food': 'Momo', 'Color': 'Pink'}

# %%
a ={"name":"Rashmi","Company":"Zapkode","Designation":"Product Head","Color":"Red"}

x= a["Color"]
print(x)
# Out:
# Red

# %%
a ={"name":"Rashmi","Company":"Zapkode","Designation":"Product Head","Color":"Red"}

x=a.get("Color")
print(x)
# Out:
# Red

# %%
a= {
    "name":"Rashmi",
    "Place":"Nainital",
    "Number":5
}
x1= a.keys()
x2= a.values()
x3= a.items()
print(x1)
print(x2)
print(x3)
# Out:
# dict_keys(['name', 'Place', 'Number'])
# dict_values(['Rashmi', 'Nainital', 5])
# dict_items([('name', 'Rashmi'), ('Place', 'Nainital'), ('Number', 5)])

# %%
a= {
    "Brand":"Maruti",
    "Model":"Ertiga",
    "Year":2019
}
a["Year"]=2018
print(a)
# Out:
# {'Brand': 'Maruti', 'Model': 'Ertiga', 'Year': 2018}

# %%
a= {
    "Brand":"Maruti",
    "Model":"Ertiga",
    "Year":2019
}
a["Years"]=2018
print(a)
# Out:
# {'Brand': 'Maruti', 'Model': 'Ertiga', 'Year': 2019, 'Years': 2018}

# %%
b= {
    "Brand":"Maruti",
    "Model":"Ertiga",
    "Year":2019
}
b.update({"year":2021})
print(b)
# Out:
# {'Brand': 'Maruti', 'Model': 'Ertiga', 'Year': 2019, 'year': 2021}

# %%
b= {
    "Brand":"Maruti",
    "Model":"Ertiga",
    "Year":2020
}
b.update({"years":2021})
print(b)
# Out:
# {'Brand': 'Maruti', 'Model': 'Ertiga', 'Year': 2020, 'years': 2021}

# %%
e= {
    "Brand":"Maruti Suzuki",
    "Model":"Ertiga",
    "Year":2020
}
e.pop("Model")
print(e)
# Out:
# {'Brand': 'Maruti Suzuki', 'Year': 2020}

# %%
e= {
    "Brand":"Maruti Suzuki",
    "Model":"Ertiga",
    "Year":2020
}
e.popitem()
print(e)
# Out:
# {'Brand': 'Maruti Suzuki', 'Model': 'Ertiga'}

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
del a["Model"]
print(a)
# Out:
# {'Brand': 'Maruti Suzuki', 'Year': 2020}

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
for x in a:
    print(x)
# Out:
# Brand
# Model
# Year

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
for y in a:
    print(a[y])
# Out:
# Maruti Suzuki
# Ertiga
# 2020

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
for a in a.values():
    print(a)
# Out:
# Maruti Suzuki
# Ertiga
# 2020

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
for b in a.keys():
    print(b)
# Out:
# Brand
# Model
# Year

# %%
a= {"Brand":"Maruti Suzuki","Model":"Ertiga","Year":2020}
for c in a.items():
    print(c)
# Out:
# ('Brand', 'Maruti Suzuki')
# ('Model', 'Ertiga')
# ('Year', 2020)

# %%
a= {'name':'rashmi','age':'40','area':'nagpur','mobile':'9511761157'}

for key,value in a.items():
    if key== 'area':
        continue
    print(key,value)
# Out:
# name rashmi
# age 40
# mobile 9511761157

# %%
a= {'name':'rashmi','age':'40','area':'nagpur','mobile':'9511761157'}

for key,value in a.items():
    if key== 'area':
        break
    print(key,value)
# Out:
# name rashmi
# age 40

# %%
#  27-03-2025--------------
