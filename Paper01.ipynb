# %%
# 01
name= "Nikhilesh"
age= 28
height= 5.8

print("Full Name ","=",name," ",age," ", height)
# Out:
# Full Name  = Nikhilesh   28   5.8

# %%
# 02

num1 = int(input(" enter the integer number"))
print(num1, " is a integer number")
print(type(num1))

num2 = float(input("enter the float number"))
print(num2, " is a float number")
print(type(num2))

num3 =str(input(" Enter the string charcter "))
print(num3, " is a string no")
print(type(num3))
# Out:
#  enter the integer number 2
# 2  is a integer number
# <class 'int'>
# enter the float number 2.5
# 2.5  is a float number
# <class 'float'>
#  Enter the string charcter  nikhilesh
# nikhilesh  is a string no
# <class 'str'>

# %%
# 03 

first = str(input(" enter first name"))
mid = str(input(" enter mid name"))
last = str(input(" enter last name"))
First= first.upper()
Mid= mid.upper()
Last= last.upper()

print("Full upper name is : ", First," ",Mid," ",Last)
# Out:
#  enter first name nikhilesh
#  enter mid name subhash
#  enter last name patil
# Full upper name is :  NIKHILESH   SUBHASH   PATIL

# %%
# 05

name ="Nikhilesh"
age= 28
info = "My name is {} and i am {} years old".format(name,age)
format(info)
# Out:
# 'My name is Nikhilesh and i am 28 years old'

# %%
# 08
num= int(input("Enter the digit"))
if num % 2==0:
    print(num,"number is even")
else:
    print(num,"number is odd")
# Out:
# Enter the digit 53
# 53 number is odd

# %%
# 10

msg= str(input("Enter the message: "))
if "python" in msg:
    print("it is true")
else:
    print("python word is not in there ")
# Out:
# Enter the message:  java is a coding language
# python word is not in there

# %%
# 07



float(input("Enter the length"))
float(input(" Enter the height"))
area= length * height

print("area of trangle is ", area)
# Out:
# Enter the length 8.6
#  Enter the height 15.2
# area of trangle is  55.18000000000001

# %%
# 06

num1= int(input("Enter first number"))
num2= int(input("Enter the second number"))

diff= num1- num2
product= num1+num2
quotient= num1/num2

print ("the operation is ",diff," ",product," ",quotient)
# Out:
# Enter first number 5
# Enter the second number 8
# the operation is  -3   13   0.625

# %%
# 09

age =int(input("Enter the age"))
if age<13:
    print("Children")
elif age>13 and age<19:
    print("teeager")
elif age >20:
    print("adults")
else:
    print(" very old")
# Out:
# Enter the age 21
# adults
