# %%
#  Practice Set 04: String Methods

#  01

full_name = input("Enter your full name: ")
length = len(full_name)
print(length)
# Out:
# Enter your full name:  nikhilesh subhash patil
# 23

# %%
#  02

user_input = input("Enter a string: ")

print(user_input.upper())

print(user_input.lower())
# Out:
# Enter a string:  nikhilesh
# NIKHILESH
# nikhilesh

# %%
#  03


first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Enter your first name:  nikhilesh
# Enter your last name:  patil
# nikhilesh patil

# %%
#  04

sentence = input("Enter a sentence: ")
words = sentence.split()
print(words)
# Out:
# Enter a sentence:  this is a great program
# ['this', 'is', 'a', 'great', 'program']

# %%
#  05

user_input = input("Enter a string with leading and trailing spaces: ")

modified_string = user_input.strip()

print(modified_string)
# Out:
# Enter a string with leading and trailing spaces:  nikhileshpatil
# nikhileshpatil

# %%
#  06

sentence = input("Enter a sentence: ")
word = input("Enter a word to search for: ")

if sentence.find(word) != -1:
    print("Word found")
else:
    print("Word not found")
# Out:
# Enter a sentence:  i am from nagpur
# Enter a word to search for:  nagpur
# Word found

# %%
#  07

sentence = input("Enter a sentence: ")
word_to_replace = input("Enter the word to replace: ")
replacement_word = input("Enter the replacement word: ")

modified_sentence = sentence.replace(word_to_replace, replacement_word)

print(modified_sentence)
# Out:
# Enter a sentence:  python is use object
# Enter the word to replace:  use
# Enter the replacement word:  nice
# python is nice object

# %%
#  08


string = input("Enter a string: ")
substring = input("Enter the character or substring to count: ")

count = string.count(substring)
print(count)
# Out:
# Enter a string:  nikhilesh
# Enter the character or substring to count:  nik
# 1

# %%
#  09


sentence = input("Enter a sentence: ")


capitalized_sentence = sentence.title()

print(capitalized_sentence)
# Out:
# Enter a sentence:  python using string
# Python Using String

# %%
 #  10

name ="Nikhilesh"
age= 28
info = "My name is {} and i am {} years old".format(name,age)
format(info)
# Out:
# 'My name is Nikhilesh and i am 28 years old'

# %%
#  11


words = ["Hello", "world", "this", "is", "Python"]

sentence = "   ".join(words)
print(sentence)
# Out:
# Hello   world   this   is   Python

# %%
#  12

email = input("Enter an email address: ")
if "@" and "." in email:
    print("Valid email")
else:
    print("Invalid email")
# Out:
# Enter an email address:  nikhilesh@gmail.com
# Valid email

# %%
#  13

user_input = input("Enter a string: ")

reversed_string = user_input[::-1]

print(reversed_string)
# Out:
# Enter a string:  patil
# litap

# %%
#  14

sentence = input("Enter a sentence with a mix of uppercase and lowercase letters: ")


uppercase_sentence = sentence.upper()
lowercase_sentence = sentence.lower()

print("Converted to uppercase:", uppercase_sentence)
print("Converted to lowercase:", lowercase_sentence)
# Out:
# Enter a sentence with a mix of uppercase and lowercase letters:  NikHilEsh SuBhaSh PAtil
# Converted to uppercase: NIKHILESH SUBHASH PATIL
# Converted to lowercase: nikhilesh subhash patil

# %%
#  15

first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
birth_year = input("Enter your birth year: ")

print(f"Hello, {first_name} {last_name}! You were born in {birth_year}.")
# Out:
# Enter your first name:  nikhilesh
# Enter your last name:  patil
# Enter your birth year:  28
# Hello, nikhilesh patil! You were born in 28.
