# %%
thissets= {"apple","banana","mango"}
print(thissets)
# Out:
# {'mango', 'apple', 'banana'}

# %% [markdown]
# thissets= {"apple","banana","cherry"}
# thissets.add("orange")
# print(thissets)

# %%
thissets= {"apple","banana","cherry"}
tropical= {"pineapple","mango","papaya"}
thissets.update(tropical)
print(thissets)
# Out:
# {'cherry', 'papaya', 'banana', 'apple', 'pineapple', 'mango'}

# %%
set1= {"a","b","c"}
set2= {1,2,3}
set3= set1.union(set2)
print(set3)
# Out:
# {'a', 1, 'b', 2, 3, 'c'}

# %%
set1= {"a","b","c"}
set2= {1,2,3}
set1.update(set2)
print(set1)
# Out:
# {'a', 1, 'b', 2, 3, 'c'}

# %%
x= {"apple","banana","cherry"}
y= {"google","micrisoft","apple"}
z= y.difference(x)
print(z)
w= x.difference(y)
print(w)
# Out:
# {'google', 'micrisoft'}
# {'cherry', 'banana'}

# %%
var2 = ("Hello","python")+("this","is","java")
var3= "Hello","java"
print(var2)
print(type(var2))
print(var3)
print(type(var3))
# Out:
# ('Hello', 'python', 'this', 'is', 'java')
# <class 'tuple'>
# ('Hello', 'java')
# <class 'tuple'>
