# %%
import os
old_name=r"demo.txt"
new_name=r"demo1.txt"
os.rename(old_name,new_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 old_name=r"demo.txt"
#       3 new_name=r"demo1.txt"
# ----> 4 os.rename(old_name,new_name)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'demo.txt' -> 'demo1.txt'

# %%
file=open('myfiles.txt','w+')
file.write("lets learn python")
print(file.read())
import os
old_name= r"myfiles.txt"
new_name= r"myfiles1.txt"
os.rename(old_name,new_name)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 7
#       5 old_name= r"myfiles.txt"
#       6 new_name= r"myfiles1.txt"
# ----> 7 os.rename(old_name,new_name)
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'myfiles.txt' -> 'myfiles1.txt'

# %%
import os
os.remove("demo1.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import os
# ----> 2 os.remove("demo1.txt")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'demo1.txt'

# %%
import os
if os.path.exists("demo1.txt"):
    os.remove("demo1.txt")
else:
    print("the file does not exist")
# Out:
# the file does not exist

# %%
import os
os.mkdir("test")

# %%
os.rmdir("test")

# %%
import os
os.makedirs('mydata')
file_names=['file1.txt','file2.txt','file3.txt','file4.txt','file5.txt']
for file_name in file_names:
    file_path=os.path.join('mydata',file_name)
    with open (file_path,'w')as file:
        file.write(f"This is the content of {file_name}")
    print("Files are created successfull!...")
# Out:
# Files are created successfull!...
# Files are created successfull!...
# Files are created successfull!...
# Files are created successfull!...
# Files are created successfull!...

# %%
import os 
a= os.listdir('mydata')
for x in a:
    print(x)
# Out:
# .ipynb_checkpoints
# file1.txt
# file2.txt
# file3.txt
# file4.txt
# file5.txt

# %%
a =os.getcwd()
print(f'Current working directory: {a}')
# Out:
# Current working directory: C:\Users\nikhi\PythonClasses

# %%
import os
os.mkdir('Test Folder')
file=open('Test Folder/demofile.txt','w')
file.write('This is the test file')
file.close()
old_name=r'Test Folder/demofile.txt'
new_name=r'Test Folder/demofile1.txt'
os.rename(old_name,new_name)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 os.mkdir('Test Folder')
#       3 file=open('Test Folder/demofile.txt','w')
#       4 file.write('This is the test file')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Test Folder'

# %%
import os 
os.rmdir('Test Folder')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 2
#       1 import os
# ----> 2 os.rmdir('Test Folder')
#
# OSError: [WinError 145] The directory is not empty: 'Test Folder'

# %%
import shutil
original=r"myfiles.txt"
target=r"myfiles1.txt"
shutil.copyfile(original,target)
# Out:
# 'myfiles1.txt'

# %%
import shutil
source =r"mydata"
destination= r"data"
shutil.copytree(source,destination)
# Out:
# 'data'

# %%
import shutil
source =r"mydata"
data= r"data"
shutil.move(source,data)
# Out:
# 'data\\mydata'

# %%
# create a zip archive of a directory
import shutil
shutil.make_archive('myfiles','zip','data')
# Out:
# 'C:\\Users\\nikhi\\PythonClasses\\myfiles.zip'

# %%
import shutil
shutil.unpack_archive('myfiles.zip','mydata1')

# %%
import os 
shutdown=input("Shutdown you pc? (Yes/no): ")
if shutdown.lower()=='no':
    exit()
else:
    os.system("shutdown \s \t 1")
# Out:
# Shutdown you pc? (Yes/no):  y
