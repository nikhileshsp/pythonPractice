# %%
# 

a= "user123"
b= "pass123"

username= input("Enter the username: ")
password= input("Enter your password: ")
if username == a and password == b:
    print("Login Successfull! Welcome, "+username)
else:
    print("Login Failed, please check your username and dpassword")
# Out:
# Enter the username:  user123
# Enter your password:  pass123
# Login Successfull! Welcome, user123

# %%
# 

a= "user123"
b= "pass123"

username= input("Enter the username: ")
if username ==a: 
    password= input("Enter your password: ")
    if  password == b:
        print("Login Successfull! Welcome, "+username)
    else:
        print("password is incorrect .program ending")
else:
     print("username is incorrect, program ending")
# Out:
# Enter the username:  user4
# username is incorrect, program ending

# %%
# get user input for a number
num= float(input("Enter a number: "))

if num%5==0:
    result= num**2
    print("The square is: ",result)
else:
    remainder= num%5
    print("The remainder is:", remainder)
# Out:
# Enter a number:  5
# The square is:  25.0

# %%
#

num1= int(input("Enter the num1"))

num2 =int(input("Enter the num2"))

if num1 and num2 %2==0:
    print("the num1 is even")
else:
    print("the num is odd")
    if num1 == num2 %2==0:
        print("any one even")
    else:
        print("any one odd")
# Out:
# Enter the num1 4
# Enter the num2 9
# the num is odd
# any one odd

# %%
num1= int(input("Enter the num1"))

num2 =int(input("Enter the num2"))
if num1 and num2 == int:
    print("both are the interger number")
else:
    print("not a integer number")
# Out:
# Enter the num1 4
# Enter the num2 5
# not a integer number

# %% [markdown]
# #### num1= input("Enter the first number:")
# num2= input("second number")
#
# if num1.isdigit() and  num2.isdigit():
#     print("2")
# elif "." in num1 and "." in num2:
#     print("1")
# else:
#     print("0")

# %%
num1 = input("Enter the first no:")
num2 = input("Enter second ")
if num1.isdigit() and num2.isdigit():
    print("2")
elif "." in num1 and "." in num2:
    print("1")
else:
    print("0")
# Out:
# Enter the first no: 5
# Enter second  5
# 2
