# %%
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)
x= Person("Tejas","JAiswal")
x.printname()
# Out:
# Tejas JAiswal

# %%
# creating a child class parent classs
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)
# child class
class Student(Person):
    pass
x= Student("Milind","Raut")
x.printname()
# Out:
# Milind Raut

# %%
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)

class Student(Person):
    def print(self):
        print(self.firstname,self.lastname)
x= Student("Shruti","Puneker")
x.printname()
x.print()
# Out:
# Shruti Puneker
# Shruti Puneker

# %%
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)

class Student(Person):
    def __init__(self,middlename):
        self.middlename=middlename
    def print(self):
        print(self.firstname,self.lastname,self.middlename)

x= Student("Rashmi","Navin","Joshi")
x.print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11     def print(self):
#      12         print(self.firstname,self.lastname,self.middlename)
# ---> 14 x= Student("Rashmi","Navin","Joshi")
#      15 x.print()
#
# TypeError: Student.__init__() takes 2 positional arguments but 4 were given

# %%
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)

class Student(Person):
    def __init__(self,firstname,lastname,middlename):
        Person.__init__(self,firstname,lastname)
        self.middlename=middlename
    
    def printing(self):
        print(self.firstname,self.lastname,self.middlename)

x= Student("Rashmi","Navin","Joshi")
x.printing()
x.printname()
# Out:
# Rashmi Navin Joshi
# Rashmi Navin

# %%
class Person:
    def __init__(self,firstname,lastname):
        self.firstname=firstname
        self.lastname=lastname
    def printname(self):
        print(self.firstname,self.lastname)

class Student(Person):
    def __init__(self,firstname,lastname,middlename):
        super().__init__(firstname,lastname)
        self.middlename=middlename
    
    def printing(self):
        print(self.firstname,self.lastname,self.middlename)

x= Student("Rashmi","Navin","Joshi")
x.printing()
x.printname()
# Out:
# Rashmi Navin Joshi
# Rashmi Navin
