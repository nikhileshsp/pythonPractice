# %%
class A:
    def __init__(self,name,id):
        self.name=name
        self.id= id
    def customer_info1(self):
        print("customer name and id is ",self.name,self.id)

class B(A):
    def __init__(self,name,id,mname,area):
        super().__init__(name,id)
        self.mname=mname
        self.area= area
    def customer_info2(self):
        print("customer mname and area is",self.mname,self.area)

class C(A):
    def __init__(self,name,id,mname,area,lname,city):
        super().__init__(name,id)
        self.lname=lname
        self.city= city
    def customer_info3(self):
        print("customer mname and area is",self.lname,self.city)

c= C("nikhilesh",101,"subhash","hingna","patil","city")
c.customer_info1()
c.customer_info2()
c.customer_info3()
# Out:
# customer name and id is  nikhilesh 101
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 26
#      24 c= C("nikhilesh",101,"subhash","hingna","patil","city")
#      25 c.customer_info1()
# ---> 26 c.customer_info2()
#      27 c.customer_info3()
#
# AttributeError: 'C' object has no attribute 'customer_info2'

# %%
class A:
    def __init__(self,name,id):
        self.name=name
        self.id= id
    def customer_info1(self):
        print("customer name and id is ",self.name,self.id)

class B(A):
    def __init__(self,name,id,mname,area):
        super().__init__(name,id)
        self.mname=mname
        self.area= area
    def customer_info2(self):
        print("customer mname and area is",self.mname,self.area)

class C(A):
    def __init__(self,name,id,mname,area,lname,city):
        B.__init__(name,id)
        self.lname=lname
        self.city= city
    def customer_info3(self):
        print("customer lname and city is",self.lname,self.city)

class D(A):
    def __init__(self,name,id,mname,area,lname,city,pincode):
        C.__init__(self,name,id,mname,area,lname,city)
        self.pincode=pincode
    def customer_info4(self):
        print("customer pincode is",self.pincode)

d= D("nikhilesh",101,"subhash","hingna","patil","nagpur",440016)
d.customer_info1()
d.customer_info2()
d.customer_info3()
d.customer_info4()

# class E(B,C):
#     def __init__(self,name,id,mname,area,lname,city,state):
#         B.__init__(self,name,id,mname,area)
#         C.__init__(self,name,id,lname,city)
#         self.state=state
#     def customer_info5(self):
#         print("state :",self.state)
        
        

# class F(D,E):
#     def __init__(self,name,id,mname,area,lname,city,state,pincode,country):
#         D.__init__(self,name,id,pincode)
#         E.__init__(self,name,id,mname,area,lname,city,state)
#         self.country=country
#     def customer_info6(self):
#         print("country: ",self.country)
        
        
# cust = F("Nikhilesh", 1, "Subhash", "Hingna", "Patel", "Nagpur", "Maharashtra", "440016", "India")

# cust.customer_info1()
# cust.customer_info2()
# cust.customer_info3()
# cust.customer_info4()
# cust.customer_info5()
# cust.customer_info6()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 31
#      28     def customer_info4(self):
#      29         print("customer pincode is",self.pincode)
# ---> 31 d= D("nikhilesh",101,"subhash","hingna","patil","nagpur",440016)
#      32 d.customer_info1()
#      33 d.customer_info2()
#
# Cell In[15], line 26, in D.__init__(self, name, id, mname, area, lname, city, pincode)
#      25 def __init__(self,name,id,mname,area,lname,city,pincode):
# ---> 26     C.__init__(self,name,id,mname,area,lname,city)
#      27     self.pincode=pincode
#
# Cell In[15], line 18, in C.__init__(self, name, id, mname, area, lname, city)
#      17 def __init__(self,name,id,mname,area,lname,city):
# ---> 18     B.__init__(name,id)
#      19     self.lname=lname
#      20     self.city= city
#
# TypeError: B.__init__() missing 3 required positional arguments: 'id', 'mname', and 'area'

# %%
class A:
    def __init__(self,name,id):
        self.name=name
        self.id= id
    def customer_info1(self):
        print("customer name and id is ",self.name,self.id)

class B(A):
    def __init__(self,name,id,mname,area):
        super().__init__(name,id)
        self.mname=mname
        self.area=area
    def customer_info2(self):
        print("customer mname and area is :",self.mname,self.area)

class C(B):
    def __init__(self,name,id,mname,area,lname,city):
        B.__init__(self,name,id,mname,area)
        self.lname=lname
        self.city=city
    def customer_info3(self):
        print("customer lname and city: ",self.lname,self.city)

c= C("nikhilesh",101,"subhash","hingna","patil","nagpur")
c.customer_info1()
c.customer_info2()
c.customer_info3()
# Out:
# customer name and id is  nikhilesh 101
# customer mname and area is : subhash hingna
# customer lname and city:  patil nagpur

# %%
class A:
    def __init__(self,name,id):
        self.name=name
        self.id= id
    def customer_info1(self):
        print("customer name and id is ",self.name,self.id)

class B(A):
    def __init__(self,name,id,mname,area):
        super().__init__(name,id)
        self.mname=mname
        self.area=area
    def customer_info2(self):
        print("customer mname and area is :",self.mname,self.area)

class C(A):
    def __init__(self,name,id,mname,area,lname,city):
        super().__init__(name,id,mname,area)
        self.lname=lname
        self.city=city
    def customer_info3(self):
        print("customer lname and city: ",self.lname,self.city)

c= C("nikhilesh",101,"subhash","hingna","patil","nagpur")
# c= C("nikhilesh",101,"subhash")
c.customer_info1()
c.customer_info2()
c.customer_info3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 24
#      21     def customer_info3(self):
#      22         print("customer lname and city: ",self.lname,self.city)
# ---> 24 c= C("nikhilesh",101,"subhash","hingna","patil","nagpur")
#      25 # c= C("nikhilesh",101,"subhash")
#      26 c.customer_info1()
#
# Cell In[23], line 18, in C.__init__(self, name, id, mname, area, lname, city)
#      17 def __init__(self,name,id,mname,area,lname,city):
# ---> 18     super().__init__(name,id,mname,area)
#      19     self.lname=lname
#      20     self.city=city
#
# TypeError: A.__init__() takes 3 positional arguments but 5 were given
