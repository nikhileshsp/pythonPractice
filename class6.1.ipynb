# %%
# Conditional Statement 

num =18
if num>5:
    print("bigger then 5")
    if num<=15:
        print("Between 5 and 15")
# Out:
# bigger then 5

# %%
letter ="C"
if letter== "B":
    print("letter is B")
else:
    if letter =="C":
        print("letter is C")
    else:
        if letter=="A":
            print("letter is A")
        else:
           print("letter isnt A B C")
# Out:
# letter is C

# %%
num= int(input("Enter the number: "))
if num>0:
    if num %2==0:
        print("positive even number")
    else:
        print("positive odd number")
elif num<0:
    if num %2==0:
        print("Negative even number")
    else:
        print("Negative odd number")
else:
    print("Zero")
# Out:
# Enter the number:  6
# positive even number

# %%
# calculate price after discount

purchase_amount= float(input("enter the purchase amount"))
if purchase_amount>=1000:
    discount= 0.1 * purchase_amount  # 10% discount for purchase over 1000
else:
    discount=0
total_cost= purchase_amount-discount
print("Total cost agter discount: Rs.",total_cost)

# %%
 age = int(input("Enter the age"))
if age<12:
    ticket_price=5
elif age>=12 and age<65:
    ticket_price=10
else:
    ticket_price=7
print("Your ticket price is",ticket_price)
# Out:
# Enter the age 56
# Your ticket price is 10

# %%
temp= int(input("Enter the temperature"))
if temp>30:
    category="HOT "
   # print("the temp is Hot")
elif temp >20:
    category="Warm"
elif temp>=10:
    category="cool"
else:
    category="cold"
print("the temp is classified as",category)
# Out:
# Enter the temperature 45
# the temp is classified as HOT
