# %%
class A:
    def __init__(self,name,id):
        self.name=name
        self.id= id
    def customer_info1(self):
        print("customer name and id is ",self.name,self.id)

class B(A):
    def __init__(self,name,id,mname,area):
        super().__init__(self,name,id)
        self.mname=mname
        self.area= area
    def customer_info2(self):
        print("customer mname and area is",self.mname,self.area)

class C(A):
    def __init__(self,name,id,lname,city):
        A.__init__(self,name,id)
        self.lname=lname
        self.city= city
    def customer_info3(self):
        print("customer lname and city is",self.lname,self.city)

class D(A):
    def __init__(self,name,id,pincode):
        A.__init__(self,name,id)
        self.pincode=pincode
    def customer_info4(self):
        print("customer pincode is",self.pincode)

class E(B,C):
    def __init__(self,name,id,mname,area,lname,city,state):
        B.__init__(self,name,id,mname,area)
        C.__init__(self,name,id,lname,city)
        self.state=state
    def customer_info5(self):
        print("state :",self.state)
        
        

class F(D,E):
    def __init__(self,name,id,mname,area,lname,city,state,pincode,country):
        D.__init__(self,name,id,pincode)
        E.__init__(self,name,id,mname,area,lname,city,state)
        self.country=country
    def customer_info6(self):
        print("country: ",self.country)
        
        
cust = F("Nikhilesh", 1, "Subhash", "Hingna", "Patel", "Nagpur", "Maharashtra", "440016", "India")

cust.customer_info1()
cust.customer_info2()
cust.customer_info3()
cust.customer_info4()
cust.customer_info5()
cust.customer_info6()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 50
#      46     def customer_info6(self):
#      47         print("country: ",self.country)
# ---> 50 cust = F("Nikhilesh", 1, "Subhash", "Hingna", "Patel", "Nagpur", "Maharashtra", "440016", "India")
#      52 cust.customer_info1()
#      53 cust.customer_info2()
#
# Cell In[1], line 44, in F.__init__(self, name, id, mname, area, lname, city, state, pincode, country)
#      42 def __init__(self,name,id,mname,area,lname,city,state,pincode,country):
#      43     D.__init__(self,name,id,pincode)
# ---> 44     E.__init__(self,name,id,mname,area,lname,city,state)
#      45     self.country=country
#
# Cell In[1], line 33, in E.__init__(self, name, id, mname, area, lname, city, state)
#      32 def __init__(self,name,id,mname,area,lname,city,state):
# ---> 33     B.__init__(self,name,id,mname,area)
#      34     C.__init__(self,name,id,lname,city)
#      35     self.state=state
#
# Cell In[1], line 10, in B.__init__(self, name, id, mname, area)
#       9 def __init__(self,name,id,mname,area):
# ---> 10     super().__init__(self,name,id)
#      11     self.mname=mname
#      12     self.area= area
#
# TypeError: C.__init__() missing 1 required positional argument: 'city'
