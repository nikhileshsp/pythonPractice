# %%
#  01
print("Basic operations")
print("1.Addition")
print("2.substracction")
print("3.multiplication")
print("4.divide")            
print("5.percentage")
choice =input("enter your choice 1 2 3 4 or 5")
num1 = int(input("Enter the first number"))
num2= float(input("Enter the second number"))

if choice == '1':
    print(num1, "+", num2,"=", num1+num2)
elif choice== '2':
    print(num1, "-", num2,"=", num1-num2)
elif choice== '3':
    print(num1, "*", num2,"=", num1*num2)
elif choice== '4':
    print(num1, "/", num2,"=", num1/num2)
elif choice== '5':
    print(num1, "&", num2,"=", num1%num2)
else:
    print("invalid 4.divide
choice")
# Out:
# Basic operations
# 1.Addition
# 2.substracction
# 3.multiplication
# 4.divide
# 5.percentage
# enter your choice 1 2 3 4 or 5 3
# Enter the first number 4
# Enter the second number 56
# 4 * 56.0 = 224.0

# %%
#  02 

num= int(input("Enter the digit"))
if num % 2==0:
    print(num,"number is even")
else:
    print(num,"number is odd")
# Out:
# Enter the digit 58
# 58 number is even

# %%
# 03


number = int(input("Enter a number: "))
if number > 1:
    for i in range(2, number):
        if number % i == 0:
            print(f"{number} is not a prime number.")
            break
    else:
        print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# Enter a number:  5
# 5 is a prime number.

# %%
# 04

number = int(input("Enter a number: "))
factorial = 1

if number < 0:
    print("Factorial is not defined for negative numbers.")
elif number == 0:
    print("The factorial of 0 is 1.")
else:
    for i in range(1, number + 1):
        factorial *= i

    print(" the factorial of ",number," ", "is ", factorial)
# Out:
# Enter a number:  8
#  the factorial of  8   is  40320

# %%
#  05


number_to_guess = 42

print("Welcome to the Guess the Number Game!")
print("I have picked a number between 1 and 100. Can you guess what it is?")
guess = None
tries = 0

while guess != number_to_guess:
    guess = int(input("Enter your guess: "))
    tries += 1
    if guess < number_to_guess:
        print("Too low! Try again.")
    elif guess > number_to_guess:
        print("Too high! Try again.")
    else:
        print(f"Congratulations! You guessed the number in {tries} tries.")
# Out:
# Welcome to the Guess the Number Game!
# I have picked a number between 1 and 100. Can you guess what it is?
# Enter your guess:  2
# Too low! Try again.
# Enter your guess:  25
# Too low! Try again.
# Enter your guess:  12
# Too low! Try again.
# Enter your guess:  42
# Congratulations! You guessed the number in 4 tries.

# %%
user_input = input("Enter a value: ")

try:
    int(user_input) 
    print("Valid integer")
except ValueError:
    print("Invalid integer")
# Out:
# Enter a value:  45
# Valid integer

# %%
#  Arithmetic Operators:

#  01

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

sum_result = num1 + num2
difference = num1 - num2
product = num1 * num2
if num2 != 0:
    quotient = num1 / num2
else:
    quotient = "undefined (division by zero)"

print("sum result",sum_result)
print("Difference:",difference)
print("Products",product)
print("Quotient",quotient)
# Out:
# Enter the first number:  4
# Enter the second number:  5
# sum result 9.0
# Difference: -1.0
# Products 20.0
# Quotient 0.8

# %%
# 02

float(input("Enter the length"))
float(input(" Enter the height"))
area= length * height

print("area of trangle is ", area)

# %%
# 03

celsius = float(input("Enter the temperature in degrees Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(" The temperature in Fahrenheit is",fahrenheit )
# Out:
# Enter the temperature in degrees Celsius:  4
#  The temperature in Fahrenheit is 39.2

# %%
#  Comparison Operators:

#  01

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))


if num1 == num2:
    print("The two numbers are equal.")
else:
    print("The two numbers are not equal.")
# Out:
# Enter the first number:  45
# Enter the second number:  25
# The two numbers are not equal.

# %%
#  02

age= int(input(" Enter the age"))

if age<18:
    print("you are not able to vote sorry!!!")
elif age > 18:
    print("you are able to vote ")
else:
    print("invalid entry")
# Out:
#  Enter the age 45
# you are able to vote

# %%
#  Logical Operators:

#  01

num= int(input(" Enter the number"))
if num >= 10 and num <= 100:
    print("your are entered num between 10 to 100")
else:
    print("more then 100")
# Out:
#  Enter the number 1001
# more then 100

# %%
#  02 

a= "user123"
b= "pass123"

username= input("Enter the username: ")
if username ==a: 
    password= input("Enter your password: ")
    if  password == b:
        print("Login Successfull! Welcome, "+username)
    else:
        print("password is incorrect .program ending")
else:
     print("username is incorrect, program ending")
# Out:
# Enter the username:  user123
# Enter your password:  pass123
# Login Successfull! Welcome, user123

# %%
#  Assignment Operators:

#  01

number = float(input("Enter a number: "))
square = number
square *= number 
print(f"The square of {number} is {square}.")
# Out:
# Enter a number:  5
# The square of 5.0 is 25.0.

# %%
# 02

number = float(input("Enter a number: "))

number += 10
print("The updated value is ",number)
# Out:
# Enter a number:  4
# The updated value is  14.0

# %%
#  Membership Operators:

# 01

letter = input("Enter a letter: ") 
if letter in "aeiouAEIOU":
    print("Vowel ")
else:
    print("Not a vowel")
# Out:
# Enter a letter:  E
# Vowel

# %%
#  02

word = input("Enter a word: ")

if "python" in word:
    print("Contains 'python'")
else:
    print("Does not contain 'python'")
# Out:
# Enter a word:  nice python
# Contains 'python'

# %%
#  Identity Operators:

#  01

list1= "amazon"
list2= "aazon"

if list1 is list2:
    print("The two lists are identical (same object).")
else:
    print("The two lists are not identical (different objects).")
# Out:
# The two lists are not identical (different objects).

# %%
#  02

variable = "nik"

if variable is None:
    print("Variable is None")
else:
    print("Variable is not None")
# Out:
# Variable is not None
