# %%
# list in python

# %%
# indexing in a list

thislist= ["apple","banana","cherry"]
print(thislist[1])
# Out:
# banana

# %%
thislist= ["apple","banana","cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist=["Apple","banana","cherry","orange","kivi","melon","mango"]
print(thislist[2:5])
print(thislist[:4])
print(thislist[2:])
print(thislist[-4:-1])
# Out:
# ['cherry', 'orange', 'kivi']
# ['Apple', 'banana', 'cherry', 'orange']
# ['cherry', 'orange', 'kivi', 'melon', 'mango']
# ['orange', 'kivi', 'melon']

# %%
thislist =["apple","banana","cherry"]
thislist[1]="blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist= ["banana","kivi","apple","chicku","mango"]
thislist[1:2]= ["strawberry","pineapple","papaya"]
print(thislist)
# Out:
# ['banana', 'strawberry', 'pineapple', 'papaya', 'apple', 'chicku', 'mango']

# %%
thislist= ["banana","kivi","apple","chicku","mango"]
thislist[1:3]= ["strawberry","pineapple","bluebarry"]
print(thislist)
# Out:
# ['banana', 'strawberry', 'pineapple', 'bluebarry', 'chicku', 'mango']

# %%
thislist= ["banana","kivi","apple","chicku","mango"]
thislist[1:5]= ["strawberry"]
print(thislist)
# Out:
# ['banana', 'strawberry']

# %%
a=["banana","kivi","apple"]
a.insert(2,"strawberry")
print(a)
# Out:
# ['banana', 'kivi', 'strawberry', 'apple']

# %%
a=["banana","kivi","apple"]
a.append("strawberry")
print(a)
# Out:
# ['banana', 'kivi', 'apple', 'strawberry']

# %%
a=["banana","kivi","apple"]
b=["mango","strawbarry"]
a.append(b)
print(a)
# Out:
# ['banana', 'kivi', 'apple', ['mango', 'strawbarry']]

# %%
a=["banana","kivi","apple"]
b=["mango","strawbarry"]
a.extend(b)
print(a)
# Out:
# ['banana', 'kivi', 'apple', 'mango', 'strawbarry']

# %%
a=["banana","kivi","apple"]
b=["mango","strawbarry"]
c=a+b
print(c)
# Out:
# ['banana', 'kivi', 'apple', 'mango', 'strawbarry']

# %%
a=["banana","kivi","apple"]
a.remove("kivi")
print(a)
# Out:
# ['banana', 'apple']

# %%
a=["banana","kivi","apple"]
a.pop(1)
print(a)
# Out:
# ['banana', 'apple']

# %%
a=["banana","kivi","apple"]
a.pop()
print(a)
# Out:
# ['banana', 'kivi']

# %%
a=["banana","kivi","apple"]
del a[0]
print(a)
# Out:
# ['kivi', 'apple']

# %%
a=["banana","kivi","apple"]
a.clear()
print(a)
# Out:
# []

# %%
#  20-03-2025-------------------------------------------

# %%
thislist=[1,8,7,2,21,15]
print(thislist)
thislist.sort()
print(thislist)
# Out:
# [1, 8, 7, 2, 21, 15]
# [1, 2, 7, 8, 15, 21]

# %%
thislist= ["orange","mango","kivi","pineapple","banana"]
thislist.sort(reverse= True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kivi', 'banana']

# %%
def myfunc(n):
    return abs(n-50)
thislist=[100,50,65,23,83,1,0]
thislist.sort(key= myfunc)
print(thislist)
# Out:
# [50, 65, 23, 83, 1, 100, 0]

# %%
thislists=["banana","Orange","Kivi","cherry"]
thislists.sort()
print(thislist)
# Out:
# ['Kivi', 'Orange', 'banana', 'cherry']

# %%
thislist=["Banana","Orange","Kivi","cherry"]
thislist.sort(key= str.lower)
print(thislist)
# Out:
# ['Banana', 'cherry', 'Kivi', 'Orange']

# %%
thislist=["banana","Orange","Kivi","cherry"]
newlist= sorted(thislist)
print(thislist)
print(newlist)
# Out:
# ['banana', 'Orange', 'Kivi', 'cherry']
# ['Kivi', 'Orange', 'banana', 'cherry']

# %%
thislist=["banana","Orange","Kivi","Apple","Strawberry"]
thislist.sort(key=len,reverse= True)
print(thislist)
# Out:
# ['Strawberry', 'banana', 'Orange', 'Apple', 'Kivi']

# %%
thislist=["apple","banana","cherry"]
mylist=thislist.copy()
print(thislist)
print(mylist)
thislist.pop(0)
mylist.append("mango")
print(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['banana', 'cherry']
# ['apple', 'banana', 'cherry', 'mango']

# %%
thislist=["apple","banana","cherry"]
mylist=list(thislist)
print(thislist)
print(mylist)
thislist.pop(0)
mylist.extend("mango")
print(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['banana', 'cherry']
# ['apple', 'banana', 'cherry', 'm', 'a', 'n', 'g', 'o']

# %%
mylist=[["Rohit","Soham","Pravin"], ['a','b','c'],[True,False]]

for a in mylist:
    for b in a:
        print(b)
# Out:
# Rohit
# Soham
# Pravin
# a
# b
# c
# True
# False

# %%
mylist= [[1,2,3],[4,5],[6,7,8]]

total_sum =0
for a in mylist:
    for b in a:
        total_sum +=b
print("Sum of all elements:",total_sum)
# Out:
# Sum of all elements: 36

# %%
mylist= [["Soham","Harsh","Nikita"], ['Mon','Tue','Wed'],[True,False]]

print("Element at (0,1): ", mylist[0][1])
print("Element at (1,1): ", mylist[1][1])
print("Element at (2,1): ", mylist[2][1])
# Out:
# Element at (0,1):  Harsh
# Element at (1,1):  Tue
# Element at (2,1):  False

# %%
mylist =[["Meera","Priya","Siya","Rahul"],['Python','Java','C'],[True,False]]

for a in mylist:
    print("Number of element in mylist: ",len(a))
# Out:
# Number of element in mylist:  4
# Number of element in mylist:  3
# Number of element in mylist:  2

# %%
mylist= [[1,2,3],['a','b','c'],[True,False]]
for a in mylist:
    a.reverse()

print("Nested list after reverseing each sublist:", mylist)
# Out:
# Nested list after reverseing each sublist: [[3, 2, 1], ['c', 'b', 'a'], [False, True]]
