# %%
class Myclass:
    x=5
print(Myclass)
# Out:
# <class '__main__.Myclass'>

# %%
class Myclass:
    x=5
p1= Myclass()   # creating an object named p1 and printthe value of x
print(p1.x)
# Out:
# 5

# %%
# using a default constructor
class Assignments:
    check="Not done"
    # creting a method
    def done(self):
        print(self.check)
# creating an object of the class
a1= Assignments()
a1.done()
# Out:
# Not done

# %%
# using a parameterizer constructor
class Assignments:
    def __init__(self,status):
        self.status=status
        print("this is a parameterizer constructor")
    def done(self):
        print("Is assignment done",self.status)
a1= Assignments('Yes')
a1.done()
# Out:
# this is a parameterizer constructor
# Is assignment done Yes

# %%
# using a non parameterized constructor
class Assignment:
    status="Yes"
    a=10
    b=20
    # creating a non parameterized constructor
    def __init__(nik,self.a,self.b):
        print("ADDITION: ",self2.a+self2.b)
        print("This is non parameterized constructor")
    def done(self):
        print("is assignment done", self.status)
a1= Assignment(a1,self2)
a1.done()
# Out:
#   Cell In[12], line 7
#     def __init__(nik,self.a,self.b):
#                          ^
# SyntaxError: invalid syntax

# %%
# passing value
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
P1=Person("chankshi",24)
print(P1.name)
print(P1.age)
# Out:
# chankshi
# 24

# %%
# uning the words test and abc instade of self
class Person:
    def __init__(test,name):
        test.name=name
    def myfunc(abc):
        print("Hello my name is "+abc.name)
P1= Person("Jatin")
P1.myfunc()
# Out:
# Hello my name is Jatin

# %%
class Person:
    def __init__(self,name,age):
        self.a= name
        self.b= age
    def myfunc(self):
        print("Hello my name is ",self.a)
        print("Hello my age is ",self.b)

P1= Person("Nilesh",23)
P1.b=25
P1.myfunc()
# Out:
# Hello my name is  Nilesh
# Hello my age is  25

# %%
# parameterized constructor
class Person1:
    def __init__(self,name,age):
        self.name= name
        self.age= age
        # this is parameterized const
    def done(self):
        print("hello my name is",self.name)
        print("hello my age is",self.age)
A1= Person1("nilesh",25)
A1.done()
# Out:
# hello my name is nilesh
# hello my age is 25

# %%
# non parameterized constructor

class Person2:
    def __init__(self):
        print("my name is riya")
        print("my age is 25")
P1= Person2()
# Out:
# my name is riya
# my age is 25

# %%
# default

class Person3:
    def myfun(self,name,age):
        print(name)
        print(age)
P1= Person3()
P1.myfun("riya",23)
# Out:
# riya
# 23
