# %%
# my first progeam
a= "Hello World"

# %%
print(a)
# Out:
# Hello World

# %%
# learning comments
#01 Single Line Comments Using #
a= "Priya"
print(a)
# Out:
# Priya

# %%
# learning comments
#01 Multi Line Comments Using ''' '''
'''a= "Priya"
print(a)'''

print(a)
# Out:
# Priya

# %%
# Learning Type of Variables Naming
# 01 Pascal CAse : Where every 1st Letter ofevery word is capital

EmployeeNameIs= "Priya"
print(EmployeeNameIs)
# Out:
# Priya

# %%
# Learning Type of Variables Naming
# 02 Snake CAse : Where every lettr is connected via underscore_

_Employee_Name_Is= "Priya"
print(_Employee_Name_Is)
# Out:
# Priya

# %%
# Learning Type of Variables Naming
'''03  camel CAse : Where the first word is Lowercase and all the other words 1st letter is capital'''

employeeNameIs= "Priya"
print(employeeNameIs)
# Out:
# Priya

# %%
# valid and invalid variables name

a='priya'   # valid name
A= 'Priya' # valid name
_= 10       #valid name
a9= "Siya"   #valid name
#6a= "roshni"  # invalid name
#@name= "Suraj"  #invalid name

print(a)
print(A)
print(_)
print(a9)
#print(6a)
#print(@name)
# Out:
# priya
# Priya
# 10
# Siya
