# %%
# 21-03-25

# %%
thistuple=("apple")
print(type(thistuple))
# Out:
# <class 'str'>

# %%
thistuple=("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
thistuple= tuple(("apple","banana","cherry"))    # note the double  round brackets
print(thistuple)
print(type(thistuple))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
thistuple= ("apple","banana","cherry")
if "apple" in thistuple:
    print("Yes,'apple' is the fruit tuple")
# Out:
# Yes,'apple' is the fruit tuple

# %%
x= ("apple","banana","cherry")
y= list(x)
y[1]= "kiwi"
x= tuple(y)
print(x)
print(type(x))
print(type(y))
# Out:
# ('apple', 'kiwi', 'cherry')
# <class 'tuple'>
# <class 'list'>

# %%
tuple1= ("a","b","c")
tuple2= (1,2,3)
tuple3= tuple1+tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
thistuple=("apple","banana","cherry")
y=("orange","mango")
thistuple +=y
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange', 'mango')

# %%
x='apple'
y='banana'
z='kiwi'
mytuple=(x,y,z)
print(mytuple)
# Out:
# ('apple', 'banana', 'kiwi')

# %%
fruits= ("Apple","Banana","Cherry")
(green,yellow,red)= fruits
print(green)
print(yellow)
print(red)
# Out:
# Apple
# Banana
# Cherry

# %%
fruits= ("Apple","Banana","Cherry","Strawberry","Raspberry")
(green,yellow,*red)= fruits
print(green)
print(yellow)
print(red)
# Out:
# Apple
# Banana
# ['Cherry', 'Strawberry', 'Raspberry']

# %%
fruits= ("Apple","Banana","Cherry ")
mytuple= fruits*3
print(mytuple)
# Out:
# ('Apple', 'Banana', 'Cherry ', 'Apple', 'Banana', 'Cherry ', 'Apple', 'Banana', 'Cherry ')

# %%
thistuple= (1,3,7,8,7,5,4,6,8,5)
x= thistuple.count(5)
print(x)
# Out:
# 2

# %%
thistuple= (1,3,7,8,7,5,4,6,8,5)
x= thistuple.index(7)
print(x)
# Out:
# 2
